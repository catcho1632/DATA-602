# %% [markdown]
# # Data 602 Final Project Proposal
#
# ### by Catherine Cho
# #### 10-22-22

# %% [markdown]
# **1. Research Question**
#
# What types of foods have the least impact on the environment? How does this differ among plant based foods and animal based foods? The impact will be measured by its carbon footprint to process and transport the food.
#
# **2. Justification - why is this relevant to you or industry?**
#
# This is relevant to me becuase I have direct impact on the environment through the food I choose to consume. The carbon food print resulting from getting food from farm to table can be referred to as "foodprint" and most of our food comes from industrual food production. This has long made a negative impact on the environment and we as individuals should be informed on what that impact is. It is our responsibility to sustain this beautiful planet that we all call home.
#
# **3. Data Sources - did you find this data online or collect yourself? Provide links**
#
# This is a kaggle dataset as linked below:
# https://www.kaggle.com/datasets/selfvivek/environment-impact-of-food-production
#
# **4. Libraries potentially being used.**
#
# * Pandas Library: Since the dataset is delivered as a csv file, the pandas library will be utilized to manipulate the data in the form of a dataframe.
# * Numpy Library: The Numpy Library is useful for performing mathematical operations on single or multidimensional arrays so the methods in this library will be used to process numerical values that are avilable in this dataset.
# * SpaCy Library: There may be opportunities to use the SpaCy library to perform natural language processing. The food product column may need methods for cleaning and normalizing text. And lexicon recognition may also be necessary.
#
# **5. EDA and summary statistics.**
#
# The summary statistics is listed below. On first glance, it appears that farming and land use has the greatest greenhouse emissions. The data for these variables are skewed right with the median being greater than the mean. There are more excepional points on the right side of the distribution. For the variables that have the greatest impact on greenhouse emissions, it would be interesting to see the contribution from each food type.
#
# For EDA, data visualization such as histograms, scatter plots, and bar plots would seem reasonable to capture information about each food product and production process.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/815268/1396036/Food_Production.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221022%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221022T200008Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')

# %%
df.head()
# Out:
#           Food product  Land use change  Animal Feed  Farm  Processing  \
# 0  Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1         Maize (Meal)              0.3          0.0   0.5         0.1
# 2        Barley (Beer)              0.0          0.0   0.2         0.1
# 3              Oatmeal              0.0          0.0   1.4         0.0
# 4                 Rice              0.0          0.0   3.6         0.1
#
#    Transport  Packging  Retail  Total_emissions  \
# 0        0.1       0.1     0.1              1.4
# 1        0.1       0.1     0.0              1.1
# 2        0.0       0.5     0.3              1.1
# 3        0.1       0.1     0.0              1.6
# 4        0.1       0.1     0.1              4.0
#
#    Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  ...  \
# 0                                                NaN         ...
# 1                                                NaN         ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 23 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Food product                                                             43 non-null     object
#  1   Land use change                                                          43 non-null     float64
#  2   Animal Feed                                                              43 non-null     float64
#  3   Farm                                                                     43 non-null     float64
#  4   Processing                                                               43 non-null     float64
#  5   Transport                                                                43 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Land use change  Animal Feed       Farm  Processing  Transport  \
# count        43.000000    43.000000  43.000000   43.000000  43.000000
# mean          1.260465     0.453488   3.469767    0.253488   0.195349
# std           3.357730     0.919200   7.083264    0.372475   0.158795
# min          -2.100000     0.000000   0.100000    0.000000   0.000000
# 25%           0.000000     0.000000   0.350000    0.000000   0.100000
# 50%           0.200000     0.000000   0.800000    0.100000   0.100000
# 75%           0.800000     0.000000   2.200000    0.300000   0.200000
# max          16.300000     2.900000  39.400000    1.300000   0.800000
#
#         Packging     Retail  Total_emissions  \
# count  43.000000  43.000000        43.000000
# mean    0.269767   0.069767         5.972093
# std     0.342633   0.110270        10.501753
# min     0.000000   0.000000         0.200000
# 25%     0.100000   0.000000         0.850000
# 50%     0.100000   0.000000         1.600000
# ...
