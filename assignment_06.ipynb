# %% [markdown]
# # Assignment 6
# ## Catherine Cho
#
# ### Dataset 1

# %%
import pandas as pd

# %%
# Question 1 
df1 = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/GOOG.csv")

# %%
# Question 2: There are 1258 rows and 7 columns in df1
df1
# Out:
#             Date         Open         High          Low        Close  \
# 0     2014-06-24   562.099304   569.514526   557.942139   561.532410
# 1     2014-06-25   562.168884   576.788513   562.129089   575.485657
# 2     2014-06-26   577.822815   579.264893   568.722839   572.850159
# 3     2014-06-27   574.023682   576.698975   570.662170   574.083374
# 4     2014-06-30   575.495605   576.400635   571.606995   572.134094
# ...          ...          ...          ...          ...          ...
# 1253  2019-06-17  1086.280029  1099.180054  1086.280029  1092.500000
# 1254  2019-06-18  1109.689941  1116.390015  1098.989990  1103.599976
# 1255  2019-06-19  1105.599976  1107.000000  1093.479980  1102.329956
# 1256  2019-06-20  1119.989990  1120.119995  1104.739990  1111.420044
# 1257  2019-06-21  1109.239990  1124.109985  1108.079956  1121.880005
#
#         Adj Close   Volume
# 0      561.532410  2213200
# 1      575.485657  1974700
# 2      572.850159  1746700
# ...

# %%
# Question 3: The shape attribute reveals a 2D data structure with 1258 rows and 7 columns.
df1.shape
# Out:
# (1258, 7)

# %%
# Question 3: The data types in df1 shows most floats and integers for the volume column. The date is an object. 
df1.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# Question 4: The describe command reveals quick summary statistics of each column in df1. The statistics output generally look pretty similar between columns.
df1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    842.065785   849.196733   834.607101   842.175733   842.175733
# std     224.688021   227.042283   222.565409   224.969453   224.969453
# min     491.942810   493.261566   484.891632   489.854309   489.854309
# 25%     645.425003   650.681763   637.150024   643.905029   643.905029
# 50%     795.364990   801.023010   790.855011   795.359985   795.359985
# 75%    1051.584992  1064.093719  1040.893494  1052.059967  1052.059967
# max    1274.000000  1289.270020  1266.295044  1287.579956  1287.579956
#
#              Volume
# count  1.258000e+03
# mean   1.750196e+06
# std    8.586929e+05
# min    5.272000e+05
# 25%    1.243325e+06
# 50%    1.531050e+06
# 75%    1.995025e+06
# max    1.116490e+07

# %%
# Question 3: The dataframe is a 2 dimensional data structure with 1000 rows and 91 columns. 
df1.shape
# Out:
# (1258, 7)

# %%
# Question 5: The tail command shows the last 5 rows of this dataset.
df1.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1253  2019-06-17  1086.280029  1099.180054  1086.280029  1092.500000
# 1254  2019-06-18  1109.689941  1116.390015  1098.989990  1103.599976
# 1255  2019-06-19  1105.599976  1107.000000  1093.479980  1102.329956
# 1256  2019-06-20  1119.989990  1120.119995  1104.739990  1111.420044
# 1257  2019-06-21  1109.239990  1124.109985  1108.079956  1121.880005
#
#         Adj Close   Volume
# 1253  1092.500000   941600
# 1254  1103.599976  1386700
# 1255  1102.329956  1338800
# 1256  1111.420044  1262000
# 1257  1121.880005  1930100

# %% [markdown]
# ### Dataset 2

# %%
# Question 1
df2 = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/nba.csv")

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
# Question 2: There are 458 rows and 9 columns in df2
df2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Question 3: The data types in df1 shows most floats and integers for the volume column. The date is an object.
df2.shape
# Out:
# (458, 9)

# %%
# Question 3: The name, team, position, height, and college are all string objects. The number, age, weight, and salary are floats. 
df2.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
# Question 4: The quick summary statistics are calculated for each column or parameter. To list a few outputs, the mean weight is 222 lbs, mean salary is 4.8 million. The interquartile statistics are listed as well as the max and mins of the dataset. 
df2.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# Question 5: The first 5 rows are listed. 
df2.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Question 5: The last 5 rows are listed. 
df2.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# ### Dataset 3

# %%
# Question 1 
df3 = pd.read_json("https://data.cityofnewyork.us/resource/ic3t-wcy2.json")

# %%
# Question 2: df3 has 1000 rows and 91 columns. 
pd.set_option("display.max_columns", None)
df3
# Out:
#          job__  doc__   borough   house__          street_name    block  \
# 0    322158650      1  BROOKLYN  3402 GAR             AVENUE P   7707.0
# 1    301776077      1  BROOKLYN       208    NORTH    8 STREET   2321.0
# 2    301776291      1  BROOKLYN       933            51 STREET   5645.0
# 3    302163557      1  BROOKLYN        96       ROCKWELL PLACE   2106.0
# 4    301775835      1  BROOKLYN        23           ASH STREET   2477.0
# ..         ...    ...       ...       ...                  ...      ...
# 995  301909095      1  BROOKLYN      2250     WEST   11 STREET   7137.0
# 996  321599329      1  BROOKLYN       971          56TH STREET   5680.0
# 997  301905598      1  BROOKLYN       752  CONEY ISLAND AVENUE   5378.0
# 998  440737552      1    QUEENS    122-12           MILBURN ST  12702.0
# 999  301909095      2  BROOKLYN      2250     WEST   11 STREET   7137.0
#
#         lot    bin__ job_type job_status                job_status_descrp  \
# ...

# %%
# Question 3: The dataframe is a 2 dimensional data structure with 1000 rows and 91 columns. 
df3.shape
# Out:
# (1000, 91)

# %%
# Question 3: The general data type of each column is an integer or string object. 
df3.dtypes
# Out:
# job__            int64
# doc__            int64
# borough         object
# house__         object
# street_name     object
#                  ...
# boiler          object
# zoning_dist3    object
# fuel_burning    object
# fuel_storage    object
# standpipe       object
# Length: 91, dtype: object

# %%
# Question 4: The quick statistics are calculated for each column value. The mean, mean, standard deviation, min, max, first and third quartile is calculated. 
df3.describe()
# Out:
#               job__        doc__         block          lot         bin__  \
# count  1.000000e+03  1000.000000    998.000000   998.000000  1.000000e+03
# mean   3.046461e+08     1.129000   4079.624248   268.876754  3.064609e+06
# std    1.040419e+08     0.553774   3451.312661  1268.409438  1.091165e+06
# min    1.025109e+08     1.000000     23.000000     1.000000  1.000816e+06
# 25%    3.017846e+08     1.000000   1318.000000    14.250000  3.006263e+06
# 50%    3.018763e+08     1.000000   3128.500000    32.500000  3.158501e+06
# 75%    3.408113e+08     1.000000   6216.000000    55.000000  3.414134e+06
# max    5.402296e+08     6.000000  16119.000000  9001.000000  5.868595e+06
#
#        community___board  applicant_license__  existing_zoning_sqft  \
# count        1000.000000           967.000000          1.000000e+03
# mean          296.234000         51986.740434          5.893012e+03
# std           103.227192         54579.624306          1.254054e+05
# ...

# %%
# Question 5: The first 5 rows are displayed. 
df3.head()
# Out:
#        job__  doc__   borough   house__        street_name   block     lot  \
# 0  322158650      1  BROOKLYN  3402 GAR           AVENUE P  7707.0    38.0
# 1  301776077      1  BROOKLYN       208  NORTH    8 STREET  2321.0     8.0
# 2  301776291      1  BROOKLYN       933          51 STREET  5645.0    66.0
# 3  302163557      1  BROOKLYN        96     ROCKWELL PLACE  2106.0  7501.0
# 4  301775835      1  BROOKLYN        23         ASH STREET  2477.0    60.0
#
#      bin__ job_type job_status                job_status_descrp  \
# 0  3419058       DM          A                       PRE-FILING
# 1  3061967       A2          X                       SIGNED OFF
# 2  3137917       A1          X                       SIGNED OFF
# 3  3059160       A1          R  PERMIT ISSUED - ENTIRE JOB/WORK
# 4  3063679       A2          X                       SIGNED OFF
#
#   latest_action_date building_type  community___board cluster landmarked  \
# ...

# %%
# Question 5: The last five rows are displayed. 
df3.tail()
# Out:
#          job__  doc__   borough house__          street_name    block   lot  \
# 995  301909095      1  BROOKLYN    2250     WEST   11 STREET   7137.0   1.0
# 996  321599329      1  BROOKLYN     971          56TH STREET   5680.0  55.0
# 997  301905598      1  BROOKLYN     752  CONEY ISLAND AVENUE   5378.0  44.0
# 998  440737552      1    QUEENS  122-12           MILBURN ST  12702.0  54.0
# 999  301909095      2  BROOKLYN    2250     WEST   11 STREET   7137.0   1.0
#
#        bin__ job_type job_status                job_status_descrp  \
# 995  3322157       A2          X                       SIGNED OFF
# 996  3139588       A1          R  PERMIT ISSUED - ENTIRE JOB/WORK
# 997  3126333       A2          X                       SIGNED OFF
# 998  4273659       A2          R  PERMIT ISSUED - ENTIRE JOB/WORK
# 999  3322157       A2          X                       SIGNED OFF
#
#     latest_action_date building_type  community___board cluster landmarked  \
# ...

# %% [markdown]
# ### Dataset 4

# %%
# Question 1: Data is extracted from Data.world
df4 = pd.read_csv("https://query.data.world/s/3e5qge5cb645dcjduqr2cud56dtz2r")

# %%
df4
# Out:
#         Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0       Confirmed    319           1  4/11/2020      Mauritius            NaN
# 1          Deaths      0           0  2/27/2020        Bahamas            NaN
# 2       Confirmed     16           0  2/16/2020        Germany            NaN
# 3          Deaths      0           0  1/31/2020         Canada        Alberta
# 4          Deaths      0           0   3/4/2020      Australia     Queensland
# ...           ...    ...         ...        ...            ...            ...
# 582655     Deaths      0           0  1/22/2020             US    Mississippi
# 582656  Confirmed      0           0  1/22/2020             US        Alabama
# 582657  Confirmed      0           0  1/22/2020             US      Tennessee
# 582658     Deaths      0           0  1/22/2020             US      Louisiana
# 582659     Deaths      0           0  1/22/2020             US     New Jersey
#
# ...

# %%
# Question 2: df4 has 582669 rows and 13 columns
df4
# Out:
#         Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0       Confirmed    319           1  4/11/2020      Mauritius            NaN
# 1          Deaths      0           0  2/27/2020        Bahamas            NaN
# 2       Confirmed     16           0  2/16/2020        Germany            NaN
# 3          Deaths      0           0  1/31/2020         Canada        Alberta
# 4          Deaths      0           0   3/4/2020      Australia     Queensland
# ...           ...    ...         ...        ...            ...            ...
# 582655     Deaths      0           0  1/22/2020             US    Mississippi
# 582656  Confirmed      0           0  1/22/2020             US        Alabama
# 582657  Confirmed      0           0  1/22/2020             US      Tennessee
# 582658     Deaths      0           0  1/22/2020             US      Louisiana
# 582659     Deaths      0           0  1/22/2020             US     New Jersey
#
# ...

# %%
# Question 3: The shape function shows that df4 is a 2d data structure with 582669 rows and 13 columns. 
df4.shape
# Out:
# (582660, 13)

# %%
# Question 3: columns such as case_type, date, country_region, province_state, admin2, combined_key are string objects. Variables such as cases, difference, FIPS, Lat, Long are float types. 
df4.dtypes
# Out:
# Case_Type             object
# Cases                  int64
# Difference             int64
# Date                  object
# Country_Region        object
# Province_State        object
# Admin2                object
# Combined_Key          object
# FIPS                 float64
# Lat                  float64
# Long                 float64
# Table_Names           object
# Prep_Flow_Runtime     object
# dtype: object

# %%
# Question 4: The quick summary statistics is calculated for all 13 columns. 
df4.describe()
# Out:
#                Cases     Difference           FIPS            Lat  \
# count  582660.000000  582660.000000  522402.000000  582494.000000
# mean       52.743324       3.494738   30335.484906      36.053549
# std      1629.455068      98.058567   15196.102883      11.404614
# min         0.000000   -1314.000000      60.000000     -51.796300
# 25%         0.000000       0.000000   18169.000000      33.616408
# 50%         0.000000       0.000000   29171.000000      37.946365
# 75%         0.000000       0.000000   45079.000000      41.683301
# max    170099.000000   25615.000000   56045.000000      71.706900
#
#                 Long
# count  582494.000000
# mean      -80.938426
# std        40.635204
# min      -170.132000
# 25%       -97.478503
# 50%       -88.688962
# 75%       -81.167718
# max       178.065000

# %%
# Question 5: The first 5 rows are displayed. 
df4.head()
# Out:
#    Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 0  Confirmed    319           1  4/11/2020      Mauritius            NaN
# 1     Deaths      0           0  2/27/2020        Bahamas            NaN
# 2  Confirmed     16           0  2/16/2020        Germany            NaN
# 3     Deaths      0           0  1/31/2020         Canada        Alberta
# 4     Deaths      0           0   3/4/2020      Australia     Queensland
#
#   Admin2 Combined_Key  FIPS      Lat      Long  Table_Names  \
# 0    NaN          NaN   NaN -20.2000   57.5000  Time Series
# 1    NaN          NaN   NaN  25.0343  -77.3963  Time Series
# 2    NaN          NaN   NaN  51.0000    9.0000  Time Series
# 3    NaN          NaN   NaN  53.9333 -116.5765  Time Series
# 4    NaN          NaN   NaN -28.0167  153.4000  Time Series
#
#       Prep_Flow_Runtime
# 0  4/13/2020 9:18:41 PM
# 1  4/13/2020 9:18:41 PM
# 2  4/13/2020 9:18:41 PM
# 3  4/13/2020 9:18:41 PM
# 4  4/13/2020 9:18:41 PM

# %%
# Question 5: The last 5 rows are displayed. 
df4.tail()
# Out:
#         Case_Type  Cases  Difference       Date Country_Region Province_State  \
# 582655     Deaths      0           0  1/22/2020             US    Mississippi
# 582656  Confirmed      0           0  1/22/2020             US        Alabama
# 582657  Confirmed      0           0  1/22/2020             US      Tennessee
# 582658     Deaths      0           0  1/22/2020             US      Louisiana
# 582659     Deaths      0           0  1/22/2020             US     New Jersey
#
#             Admin2               Combined_Key     FIPS        Lat       Long  \
# 582655     Hancock   Hancock, Mississippi, US  28045.0  30.418302 -89.488510
# 582656      Etowah        Etowah, Alabama, US   1055.0  34.045673 -86.040519
# 582657  Montgomery  Montgomery, Tennessee, US  47125.0  36.496094 -87.385507
# 582658     Lincoln     Lincoln, Louisiana, US  22061.0  32.600315 -92.665974
# 582659      Warren     Warren, New Jersey, US  34041.0  40.859518 -74.995565
#
# ...

# %% [markdown]
# ### Extra Credit:

# %%
# 1. Choose one of your datasets and remove the header information. (Can delete the row in excel, etc..)
# df1 is chosen for this extra credit.
df1.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#     Volume
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300

# %%
df1
df1.columns = range(df1.shape[1])
# Next, the 0 index label is dropped. 
df1.head()
# Out:
#             0           1           2           3           4           5  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#          6
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300

# %%
#2. Import the data into your environment using pandas. Display the .head() of your data showing no header information. 
df1_no_header = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/GOOG.csv",header = None)
# Since the header row has been assigned to the first row, the first row is dropepd then the index is re-set. 
df1_no_header = (df1_no_header.drop(0)).reset_index(drop = True)
df1_no_header.head()
# Out:
#             0           1           2           3           4           5  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#          6
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300

# %%
#3. Using pandas, update the dataset to include the header information. Display the updated data using .head().

# %%
# The csv is read back in without the header such that the "header" row is assigned to the first row for the purpose of this exercise.  
df1_no_header = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/GOOG.csv",header = None)
df1_no_header.head()
# Out:
#             0           1           2           3           4           5  \
# 0        Date        Open        High         Low       Close   Adj Close
# 1  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 2  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 3  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 4  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
#
#          6
# 0   Volume
# 1  2213200
# 2  1974700
# 3  1746700
# 4  2243000

# %%
# The header is re-defined by the first row of df1_no_header. 
df1_no_header.columns = df1_no_header.iloc[0]
# the index is re-set after dropping the row of index 0. 
df1_no_header = (df1_no_header.drop(0)).reset_index()
df1_no_header.head()
# Out:
# 0  index        Date        Open        High         Low       Close  \
# 0      1  2014-06-24  562.099304  569.514526  557.942139  561.532410
# 1      2  2014-06-25  562.168884  576.788513  562.129089  575.485657
# 2      3  2014-06-26  577.822815  579.264893  568.722839  572.850159
# 3      4  2014-06-27  574.023682  576.698975  570.662170  574.083374
# 4      5  2014-06-30  575.495605  576.400635  571.606995  572.134094
#
# 0   Adj Close   Volume
# 0  561.532410  2213200
# 1  575.485657  1974700
# 2  572.850159  1746700
# 3  574.083374  2243000
# 4  572.134094  1317300
